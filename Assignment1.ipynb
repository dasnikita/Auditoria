# %%
import pandas as pd
import numpy as np
import matplotlib as pl
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing a dataset

# %%
data = pd.read_csv("fitness analysis.csv")
data
# Out:
#                            Timestamp    Your name  Your gender      Your age   \
# 0    2019/07/03 11:48:07 PM GMT+5:30       Parkavi       Female      19 to 25
# 1    2019/07/03 11:51:22 PM GMT+5:30      Nithilaa       Female      19 to 25
# 2    2019/07/03 11:56:28 PM GMT+5:30     Karunya v       Female      15 to 18
# 3     2019/07/04 5:43:35 AM GMT+5:30       Anusha        Female      15 to 18
# 4     2019/07/04 5:44:29 AM GMT+5:30      Nikkitha       Female      19 to 25
# ..                               ...           ...          ...           ...
# 540   2019/07/09 7:46:49 PM GMT+5:30         Kousi       Female  40 and above
# 541   2019/07/09 8:20:48 PM GMT+5:30       Dhanuja       Female  40 and above
# 542  2019/07/12 11:22:18 AM GMT+5:30    Abhinaya V       Female      19 to 25
# 543   2019/07/15 1:48:25 PM GMT+5:30      Vishnu S         Male      19 to 25
# 544   2019/07/21 8:54:46 PM GMT+5:30  Mary Presley       Female  40 and above
#
# ...

# %% [markdown]
# ## analysing the number of rows and columns

# %%
data.shape
# Out:
# (545, 18)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Your name ', 'Your gender ', 'Your age ',
#        'How important is exercise to you ?',
#        'How do you describe your current level of fitness ?',
#        'How often do you exercise?',
#        'What barriers, if any, prevent you from exercising more regularly?           (Please select all that apply)',
#        'What form(s) of exercise do you currently participate in ?                        (Please select all that apply)',
#        'Do you exercise ___________ ?',
#        'What time if the day do you prefer to exercise?',
#        'How long do you spend exercising per day ?',
#        'Would you say you eat a healthy balanced diet ?',
#        'What prevents you from eating a healthy balanced diet, If any?                         (Please select all that apply)',
#        'How healthy do you consider yourself?',
#        'Have you ever recommended your friends to follow a fitness routine?',
#        'Have you ever purchased a fitness equipment?',
# ...

# %%
data.head(7)
# Out:
#                          Timestamp  Your name  Your gender      Your age   \
# 0  2019/07/03 11:48:07 PM GMT+5:30     Parkavi       Female      19 to 25
# 1  2019/07/03 11:51:22 PM GMT+5:30    Nithilaa       Female      19 to 25
# 2  2019/07/03 11:56:28 PM GMT+5:30   Karunya v       Female      15 to 18
# 3   2019/07/04 5:43:35 AM GMT+5:30     Anusha        Female      15 to 18
# 4   2019/07/04 5:44:29 AM GMT+5:30    Nikkitha       Female      19 to 25
# 5   2019/07/04 6:23:37 AM GMT+5:30      Girija       Female  40 and above
# 6   2019/07/04 6:33:21 AM GMT+5:30  Srinivasan         Male  40 and above
#
#    How important is exercise to you ?  \
# 0                                   2
# 1                                   4
# 2                                   3
# 3                                   4
# 4                                   3
# 5                                   5
# 6                                   3
#
#   How do you describe your current level of fitness ?  \
# ...

# %%
data.describe()
# Out:
#        How important is exercise to you ?  \
# count                          545.000000
# mean                             3.884404
# std                              0.997900
# min                              1.000000
# 25%                              3.000000
# 50%                              4.000000
# 75%                              5.000000
# max                              5.000000
#
#        How healthy do you consider yourself?
# count                             545.000000
# mean                                3.258716
# std                                 0.793495
# min                                 1.000000
# 25%                                 3.000000
# 50%                                 3.000000
# 75%                                 4.000000
# max                                 5.000000

# %% [markdown]
# ## Checking for null values

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                0
# Your name                                                                                                                0
# Your gender                                                                                                              0
# Your age                                                                                                                 0
# How important is exercise to you ?                                                                                       0
# How do you describe your current level of fitness ?                                                                      0
# How often do you exercise?                                                                                               0
# What barriers, if any, prevent you from exercising more regularly?           (Please select all that apply)              0
# ...

# %% [markdown]
# ## filtering the data for people having  a good fitness level while exercising in the evening

# %%
data.loc[(data['What time if the day do you prefer to exercise?']=='Evening') & (data['How do you describe your current level of fitness ?']=='Good')]
# Out:
#                            Timestamp        Your name  Your gender  Your age   \
# 3     2019/07/04 5:43:35 AM GMT+5:30           Anusha        Female  15 to 18
# 21    2019/07/04 8:30:50 AM GMT+5:30      Baalavignesh         Male  19 to 25
# 28    2019/07/04 8:38:45 AM GMT+5:30       Karthikessh         Male  15 to 18
# 50    2019/07/04 8:54:05 AM GMT+5:30            Rubiha       Female  19 to 25
# 53    2019/07/04 9:01:55 AM GMT+5:30     Nandhana shri       Female  15 to 18
# ..                               ...               ...          ...       ...
# 511   2019/07/06 7:07:27 PM GMT+5:30            Roshni       Female  15 to 18
# 517  2019/07/06 10:26:05 PM GMT+5:30  Varna sureshbabu       Female  15 to 18
# 528  2019/07/07 10:16:47 PM GMT+5:30          Preethi        Female  19 to 25
# 533  2019/07/09 10:16:53 AM GMT+5:30             Yalu        Female  26 to 30
# 543   2019/07/15 1:48:25 PM GMT+5:30          Vishnu S         Male  19 to 25
#
# ...

# %%
Good= data.loc[data['How do you describe your current level of fitness ?']=='Good'].shape[0]
Very_good = data.loc[data['How do you describe your current level of fitness ?']=='Very good'].shape[0]
Unfit= data.loc[data['How do you describe your current level of fitness ?']=='Unfit'].shape[0]
Average= data.loc[data['How do you describe your current level of fitness ?']=='Average'].shape[0]
Perfect= data.loc[data['How do you describe your current level of fitness ?']=='Perfect'].shape[0]
print(Good)
print(Very_good)
print(Unfit)
print(Average)
print(Perfect)
# Out:
# 220
# 53
# 54
# 195
# 23

# %% [markdown]
# ## Visualizing Data

# %%
pi_data=[Good,Very_good,Unfit,Average,Perfect]
pi_label='Good', 'Very good', 'Unfit', 'Average', 'Perfect'
plt.pie(pi_data,labels=pi_label,autopct='%1.1f%%')
plt.axis('equal')
plt.title('Percentage distribution of people based on level of fitness')
plt.show()

# %%
Perfect_F = data.loc[(data['Your gender ']=='Female') & (data['How do you describe your current level of fitness ?']=='Perfect')].shape[0]
print(Perfect_F)
Perfect_M = data.loc[(data['Your gender ']=='Male') & (data['How do you describe your current level of fitness ?']=='Perfect')].shape[0]
print(Perfect_M)
pi2_data = [Perfect_F,Perfect_M]
pi2_label = 'Female','Male'
plt.pie(pi2_data,labels=pi2_label,autopct='%1.1f%%')
plt.axis('equal')
plt.title('Gender wise percentage of people having perfect level of fitness')
plt.show()
# Out:
# 9
# 14

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
Age = data['Your age '].unique().tolist()
a1= data.loc[data['Your age ']=='15 to 18'].shape[0]
a2= data.loc[data['Your age ']=='19 to 25'].shape[0]
a3= data.loc[data['Your age ']=='26 to 30'].shape[0]
a4= data.loc[data['Your age ']=='30 to 40'].shape[0]
a5= data.loc[data['Your age ']=='40 and above'].shape[0]
x= Age
y= [a1,a2,a3,a4,a5]
ax.bar(x,y)
ax.set_xlabel('Age Groups')
ax.set_ylabel('No. of people')
ax.set_title('Frequency of age groups participating in the survey')
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([0,0,1,1])
Frequency = data['How often do you exercise?'].unique().tolist()
print(Frequency)
f1= data.loc[data['How often do you exercise?']=='Never'].shape[0]
f2= data.loc[data['How often do you exercise?']=='1 to 2 times a week'].shape[0]
f3= data.loc[data['How often do you exercise?']=='2 to 3 times a week'].shape[0]
f4= data.loc[data['How often do you exercise?']=='3 to 4 times a week'].shape[0]
f5= data.loc[data['How often do you exercise?']=='5 to 6 times a week'].shape[0]
f6= data.loc[data['How often do you exercise?']=='Everyday'].shape[0]
x= Frequency
y= [f1,f2,f3,f4,f5,f6]
ax.bar(x,y)
ax.set_xlabel('Frequency')
ax.set_ylabel('No. of people')
ax.set_title('Exercising frequency of given population')
plt.show()
# Out:
# ['Never', '1 to 2 times a week', '3 to 4 times a week', 'Everyday', '2 to 3 times a week', '5 to 6 times a week']

# %%
from arsenal.maths import compare, normalize
from arsenal.viz import contour_plot
from scipy.linalg import norm

eps = 1e-5
x0 = np.random.uniform(-1,1,size=D)
p = norm
Delta = lambda x,d: x+d
d = steepest(f, Delta, p, x0, eps=eps, visualize=True)
g0 = nd.Gradient(f)(x0)

compare(d / p(d), g0 / p(g0)).show();
#assert np.allclose(d / p(d), g0 / p(g0), rtol=0.05)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-521ccb9115a8> in <module>
# ----> 1 from arsenal.maths import compare, normalize
#       2 from arsenal.viz import contour_plot
#       3 from scipy.linalg import norm
#       4
#       5 eps = 1e-5
#
# ModuleNotFoundError: No module named 'arsenal'

# %%
from scipy.optimize import minimize
def steepest(f, Delta, p, x, eps=1e-4, visualize=False):
    """
    Find the direction of steepest ascent for the function `f`, where the direction
    is `eps` far away under norm `p` (which implicitly measures the distance from 
    the current iterate `x`).
    """
    opt = minimize(lambda d: -f(Delta(x, d)), x0 = 0*x, options = dict(maxiter = 10000),
                   constraints = [{'fun': lambda d: eps - p(d), 'type': 'ineq'}])
    assert opt.success, opt.message
    if visualize: plot_steepest(f, Delta, p, x, opt.x, eps)
    return opt.x    # output will have unit-length vector under p

# %%
import numpy as np

def gradient_descent(
    gradient, start, learn_rate, n_iter=50, tolerance=1e-06):
    vector = start
    for _ in range(n_iter):
        diff = -learn_rate * gradient(vector)
        if np.all(np.abs(diff) <= tolerance):
            break
        vector += diff
    return vector
